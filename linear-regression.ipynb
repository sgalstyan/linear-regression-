# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load data
data = pd.read_csv('data/student_performance.csv')

# Inflation Rate as X and Stock Index Value as y
X = data[['AttendanceRate']].values  # Ensure X is 2D
Y = data['FinalGrade'].values  # y is 1D

# Split the data into training and test sets (80% training, 20% testing)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Plot the data points
plt.scatter(X_train, Y_train, color='blue', label='Training Data')
plt.scatter(X_test, Y_test, color='green', label='Test Data')
plt.title('Data points')
plt.xlabel('AttendanceRate')
plt.ylabel('FinalGrade')
plt.legend()
plt.show()

# %%
# Create the Linear Regression model
model = LinearRegression()

# Train the model (fit the model to the training data)
model.fit(X_train, Y_train)

# Print the model coefficients
print(f"Slope (beta_1): {model.coef_[0]}")
print(f"Intercept (beta_0): {model.intercept_}")
# Out:
# Slope (beta_1): 1.2864806866952794
# Intercept (beta_0): -29.619098712446387

# %%
# Plot regression line
plt.scatter(X_train, Y_train, color='blue', label='Training Data')
plt.scatter(X_test, Y_test, color='green', label='Test Data')
plt.plot(X_train, model.predict(X_train), color='red', label='Regression Line')
plt.xlabel('AttendanceRate')
plt.ylabel('FinalGrade')
plt.title('Regression Line')
plt.legend()
plt.show()

# %%
# Prediction
y_pred = model.predict(X_test)

# MSE and R_square
mse = mean_squared_error(Y_test, y_pred)
r_square = r2_score(Y_test, y_pred)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-square: {r_square}")
# Out:
# Mean Squared Error (MSE): 7.846733454290904
# R-square: 0.8605025163681617
